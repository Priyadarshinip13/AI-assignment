# %% [markdown]
# Task1

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print(f"Addition: {a + b}")
print(f"Subtraction: {a - b}")
print(f"Multiplication: {a * b}")
print(f"Division: {a / b}")
print(f"Modulus: {a % b}")
print(f"Power: {a ** b}")

print(f"a > b : {a > b}")
print(f"a < b : {a < b}")
print(f"a == b : {a == b}")
print(f"a != b : {a != b}")

print(f"(a > 0 and b > 0): {a > 0 and b > 0}")
print(f"(a > 0 or b > 0): {a > 0 or b > 0}")
print(f"not(a > b): {not (a > b)}")
# Out:
# Addition: 25
# Subtraction: -1
# Multiplication: 156
# Division: 0.9230769230769231
# Modulus: 12
# Power: 106993205379072
# a > b : False
# a < b : True
# a == b : False
# a != b : True
# (a > 0 and b > 0): True
# (a > 0 or b > 0): True
# not(a > b): True

# %% [markdown]
# Task2

# %%
import random
import numpy as np

numbers = [random.randint(1, 100) for _ in range(10)]
print("Original List:", numbers)

numbers.append(50)
numbers.remove(numbers[0])
print("Updated List:", numbers)

print("Max:", max(numbers))
print("Min:", min(numbers))

numbers.sort()
print("Sorted List:", numbers)

arr = np.array(numbers)
print("Mean:", np.mean(arr))
print("Median:", np.median(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# Original List: [45, 28, 82, 86, 43, 6, 33, 28, 64, 62]
# Updated List: [28, 82, 86, 43, 6, 33, 28, 64, 62, 50]
# Max: 86
# Min: 6
# Sorted List: [6, 28, 28, 33, 43, 50, 62, 64, 82, 86]
# Mean: 48.2
# Median: 46.5
# Standard Deviation: 24.227257376764705

# %% [markdown]
# Task3

# %%
student = {
    "name": "Anu",
    "course": "AI & ML",
    "marks": 82
}

if student["marks"] >= 90:
    student["grade"] = "A"
elif student["marks"] >= 75:
    student["grade"] = "B"
else:
    student["grade"] = "C"

for key, value in student.items():
    print(key, ":", value)

set1 = {"ChatGPT", "Gemini", "Claude"}
set2 = {"Midjourney", "DALL-E", "ChatGPT"}

print("AI Tools Union:", set1.union(set2))
print("Common Tools:", set1.intersection(set2))
# Out:
# name : Anu
# course : AI & ML
# marks : 82
# grade : B
# AI Tools Union: {'Claude', 'Gemini', 'ChatGPT', 'DALL-E', 'Midjourney'}
# Common Tools: {'ChatGPT'}

# %% [markdown]
# Task4

# %%
students = [
    ("Ravi", 78, "B"),
    ("Anu", 82, "B"),
    ("Kiran", 91, "A"),
    ("Meena", 65, "C"),
    ("Ajay", 88, "A")
]

with open("ai_students.txt", "w") as file:
    for s in students:
        file.write(f"{s[0]}, {s[1]}, {s[2]}\n")

with open("ai_students.txt", "r") as file:
    print("Students scoring above 75:")
    for line in file:
        name, marks, grade = line.strip().split(", ")
        if int(marks) > 75:
            print(name, marks, grade)
# Out:
# Students scoring above 75:
# Ravi 78 B
# Anu 82 B
# Kiran 91 A
# Ajay 88 A

# %% [markdown]
# Task5

# %%
from datetime import datetime

prompt = input("Enter your AI prompt: ")

with open("prompt_history.txt", "a") as file:
    time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    file.write(f"[{time}] {prompt}\n")

print("Prompt saved successfully.")
# Out:
# Prompt saved successfully.
